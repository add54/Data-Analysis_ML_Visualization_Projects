# %% [markdown]
# <a href="https://colab.research.google.com/github/add54/-Data-Analysis-plotly-Plotly-Whirlwind-Introduction.ipynb-/blob/master/Project_4_Data_Analysis_with_Python_Covid_19_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv(r'/content/drive/MyDrive/4. covid_19_data.csv')
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
#Null values in data or missing values
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
#Import library 
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# 1. Show the Number of Confirmed , Death and Recovred cases in each Region:

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed', 'Recovered'].sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# 2. Remove all Cases records where Confirmed Cases is Less Than 10:

# %%
data.head(1)
data.Confirmed < 10
data[data.Confirmed < 10]
# Out:
#           Date                             State  ... Deaths  Recovered
# 18   4/29/2020                               NaN  ...      0          5
# 98   4/29/2020                               NaN  ...      2          0
# 105  4/29/2020                               NaN  ...      1          6
# 126  4/29/2020                               NaN  ...      0          0
# 140  4/29/2020                               NaN  ...      0          4
# 177  4/29/2020                               NaN  ...      0          5
# 178  4/29/2020                               NaN  ...      0          1
# 184  4/29/2020                          Anguilla  ...      0          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba  ...      0          0
# 194  4/29/2020            British Virgin Islands  ...      1          3
# 203  4/29/2020      Diamond Princess cruise ship  ...      1          0
# 272  4/29/2020             Northwest Territories  ...      0          0
# ...

# %%
#~ help to remove records sorting 
data[~(data.Confirmed < 10)]
data = data[~(data.Confirmed < 10)] # To remove the records satisfying a particular condition 
data.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %% [markdown]
# 3. In Which Region , maximum Number of Confirmed Cases recorded:

# %%
data = pd.read_csv(r'/content/drive/MyDrive/4. covid_19_data.csv')
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# 4.In Which Region , Minimum Number of Deaths Cases Were recorded:

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %% [markdown]
# 5. How many Confirmed , Deaths & Recovred Cases were reported from India until 29 April 2020:

# %%
data.head(2)
data[data.Region == 'India']
#data[data.Region == 'Country_name']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# 6. Sort the entire data wrt No. of Confirmed cases in ascending Order:

# %%
data.sort_values(by= ['Confirmed'], ascending=True)
# Out:
#           Date                         State  ... Deaths  Recovered
# 285  4/29/2020                     Recovered  ...      0     120720
# 284  4/29/2020                     Recovered  ...      0      20327
# 203  4/29/2020  Diamond Princess cruise ship  ...      1          0
# 305  4/29/2020                         Tibet  ...      0          1
# 289  4/29/2020     Saint Pierre and Miquelon  ...      0          0
# ..         ...                           ...  ...    ...        ...
# 57   4/29/2020                           NaN  ...  24087      48228
# 168  4/29/2020                           NaN  ...  26097          0
# 80   4/29/2020                           NaN  ...  27682      71252
# 153  4/29/2020                           NaN  ...  24275     132929
# 265  4/29/2020                      New York  ...  23477          0
#
# [321 rows x 6 columns]

# %% [markdown]
# 7. Sort Entire data wrt No. Recovered Cases in descending Order:

# %%
data.sort_values(by= ['Recovered'], ascending=False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]

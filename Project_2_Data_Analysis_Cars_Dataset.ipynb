# %% [markdown]
# <a href="https://colab.research.google.com/github/add54/-Data-Analysis-plotly-Plotly-Whirlwind-Introduction.ipynb-/blob/master/Project_2_Data_Analysis_Cars_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
car = pd.read_csv(r'/content/2. Cars Data1.csv')
car.head(2)
car.shape
#car.isnull().sum()
# Out:
# (432, 15)

# %%
car['Cylinders'].fillna(car['Cylinders'].mean(), inplace = True)
car.shape
# Out:
# (432, 15)

# %%
car['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Mitsubishi       13
# Dodge            13
# Jaguar           12
# Hyundai          12
# Volvo            12
# Mazda            11
# Lexus            11
# Kia              11
# Pontiac          11
# Subaru           11
# Lincoln           9
# Buick             9
# Mercury           9
# Infiniti          8
# Suzuki            8
# GMC               8
# Cadillac          8
# Saturn            8
# Acura             7
# Porsche           7
# Saab              7
# Jeep              3
# Land Rover        3
# Oldsmobile        3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# 3. Filetring Instruction: Show all records where origin in Asia or Europe:

# %%
car.head(1)
car[car['Origin'].isin(['Asia', 'Europe'])]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [281 rows x 15 columns]

# %% [markdown]
# 4. Removing Unwanted records : remove all records where Weight is above 4000:

# %%
car[~(car['Weight'] > 4000)]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan  ...  3893.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [329 rows x 15 columns]

# %% [markdown]
# 5. Applying instruction function on columns Increase all the values of 'MPG_City by 3:

# %%
car['MPG_City] = car['MPG_City'].apply(lambda x:x+3)
